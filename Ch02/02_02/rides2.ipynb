# %%
import rides

# %% [markdown]
# ## Load Data

# %%
df = rides.load_rides('../../data/bikes.ddb')
print('size:', len(df))
# Out:
# size: 649231

# %% [markdown]
# ## Clean Data

# %%
df = rides.clean_rides(df)
print('size:', len(df))
# Out:
# size: 603770

# %% [markdown]
# ## Run Calculations

# %%
bike_id, duration = rides.bike_with_most_time(df)
print(f'longest duration: {bike_id=}: {duration}')
# Out:
# longest duration: bike_id=5089: 3914
